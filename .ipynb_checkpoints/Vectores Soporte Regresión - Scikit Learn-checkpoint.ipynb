# %% [markdown]
# # Como usar esta librería para implementar este algoritmo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Comando a utilizar en un algoritmo de Vectores de Sorporte de Regresión:**

# %% [markdown]
# ![image.png](attachment:image.png)
