# %% [markdown]
# # K-Near Neighboors (Práctica)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **PRÁCTICA**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
#Obtenemos el dataset de CANCER de la librería de SCIKITLEARN
dataset = datasets.load_breast_cancer()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
#Seleccionamos todas las columnas
X = dataset.data

#Defino los datos correspondientes a las etiquetas
Y = dataset.target

# %% [markdown]
# **IMPLEMENTACIÓN DE K VECINOS MÁS CERCANOS**

# %%
from sklearn.model_selection import train_test_split

#Separo los datos de "train" en entrenamiento y prueba
#para poder probar los algoritmos

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %%
#Defino el algoritmo a utilizar
from sklearn.neighbors import KNeighborsClassifier

# %%
algoritmo = KNeighborsClassifier(n_neighbors= 5, metric='minkowski', p=2)
#estas métricas viene por defecto de esta forma
#si quisieramos, se podría dejar el paréntesis vacío
#pero se muestran las 3 métricas a modod e enseñanza

# %%
#entreno el modelo
algoritmo.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
#Realizo una predicción
Y_pred = algoritmo.predict(X_test)

# %%
#Para validar que el modelo funciona, se verifica la
#Matríz de confusión (ver en video de curso)

from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(Y_test, Y_pred)
print('Matriz de COnfusión:')
print(matriz)
# Out:
# Matriz de COnfusión:
# [[41  4]
#  [ 1 68]]

# %% [markdown]
# **La diagonal Principal** indica la cantidad de datos predichos correctamente, y **La diagonal secundaria** son los errores. En este caso es mayor la cantidad de datos correctos que incorrectos. La suma de la diagonal principal es 109 e incorrectos 5.

# %%
#Validar la precisión del modelo
from sklearn.metrics import precision_score

precision = precision_score(Y_test, Y_pred)
print('Precisión del modelo:')
print(precision)
# Out:
# Precisión del modelo:
# 0.9444444444444444
